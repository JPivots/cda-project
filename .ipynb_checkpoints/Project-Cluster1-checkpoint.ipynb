# %% [markdown]
# # Project

# %%
import numpy as np
import random
import math
from math import pi
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy.io as spio
from IPython.display import display
import scipy.sparse.linalg as ll
from scipy.spatial.distance import cdist
from sklearn.metrics import pairwise_distances
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import shortest_path
import sklearn.utils.graph_shortest_path as skug
from scipy.linalg import svd
from scipy import stats

from sklearn.cluster import KMeans

from sklearn.neighbors import KernelDensity
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# from plotly.subplots import make_subplots

# %matplotlib inline

# %%
# Read in the data
DATA_PATH = "data/"
spotify_artists_top_tracks_df = pd.read_csv('{}spotify_artists_top_tracks.csv'.format(DATA_PATH))
print("{} x {} table of data:".format(spotify_artists_top_tracks_df.shape[0], spotify_artists_top_tracks_df.shape[1]))
display(spotify_artists_top_tracks_df.head ())
print("Remove any N/As...\n\n")
spotify_artists_top_tracks_df = spotify_artists_top_tracks_df.dropna()
print("{} x {} table of data:".format(spotify_artists_top_tracks_df.shape[0], spotify_artists_top_tracks_df.shape[1]))
display(spotify_artists_top_tracks_df.head ())
print(spotify_artists_top_tracks_df.columns.tolist())
# Out:
# 17306 x 24 table of data:
#                               artist_uri artist_name albumn_name  \
# 0  spotify:artist:7urq0VfqxEYEEiZUkebXT4         112    Part III
# 1  spotify:artist:7urq0VfqxEYEEiZUkebXT4         112         112
# 2  spotify:artist:7urq0VfqxEYEEiZUkebXT4         112    Part III
# 3  spotify:artist:7urq0VfqxEYEEiZUkebXT4         112         112
# 4  spotify:artist:7urq0VfqxEYEEiZUkebXT4         112    Part III
#
#   albumn_release_date  albumn_total_tracks  duration_ms  explicit  \
# 0                2001                   16       193093     False
# 1           8/27/1996                   19       289413     False
# 2                2001                   16       231800     False
# 3           8/27/1996                   19       252266     False
# 4                2001                   16       264933     False
#
#                                           track_name  track_popularity  \
# 0                                    Peaches & Cream                65
# 1  Only You (feat. The Notorious B.I.G. & Mase) -...                64
# 2                                      Dance With Me                64
# 3                                              Cupid                63
# 4                                      It's Over Now                60
#
#                               track_uri  ...  mode  speechiness  acousticness  \
# 0  spotify:track:2SLZ2rX5773RS16mcqBxG7  ...     0       0.3340       0.00277
# 1  spotify:track:6zOg9gP62RJSsKFeOBAgvH  ...     1       0.0480       0.02960
# 2  spotify:track:6uRH1qMz30ZBwwUG0IYE5s  ...     1       0.2030       0.02590
# 3  spotify:track:3kVIFDE3G89I2RPVkiRaRj  ...     1       0.1120       0.37300
# 4  spotify:track:769geiA8btidGHda4BBDOJ  ...     1       0.0409       0.01060
#
#    instrumentalness  liveness  valence    tempo  time_signature  \
# 0          0.000000    0.0532    0.768  203.862               4
# 1          0.000000    0.0993    0.787   95.813               4
# 2          0.000000    0.0442    0.611  101.628               4
# 3          0.000000    0.0371    0.870  175.562               4
# 4          0.000007    0.0736    0.233   97.988               4
#
#    cluster_number  km_nn9_nc3
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
#
# [5 rows x 24 columns]
# Remove any N/As...
#
#
# 5542 x 24 table of data:
#                                artist_uri     artist_name  \
# 40  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  10,000 Maniacs
# 41  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  10,000 Maniacs
# 42  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  10,000 Maniacs
# 43  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  10,000 Maniacs
# 44  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  10,000 Maniacs
#
#              albumn_name albumn_release_date  albumn_total_tracks  \
# 40         MTV Unplugged          10/26/1993                   14
# 41      Our Time in Eden                1992                   13
# 42  Love Among The Ruins            1/1/1997                   12
# 43       Blind Man's Zoo            5/2/1989                   11
# 44      Our Time in Eden                1992                   13
#
#     duration_ms  explicit                          track_name  \
# 40       223373     False  Because the Night - Live Unplugged
# 41       219893     False                      These Are Days
# 42       245573     False                      More Than This
# 43       193560     False                          Trouble Me
# 44       185960     False               Candy Everybody Wants
#
#     track_popularity                             track_uri  ...  mode  \
# 40                61  spotify:track:5VzvK7YiwWbRePA2JOzhYq  ...     0
# 41                56  spotify:track:786h4kDeZiX5nYvOwA3wtE  ...     1
# 42                53  spotify:track:5v6b9RUk83Z33shcsqt1m3  ...     1
# 43                50  spotify:track:5nLhswlXx18vI65KkKKFgx  ...     1
# 44                47  spotify:track:32xXojNvbRTQ9qfb3mWR69  ...     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 40       0.1030        0.2600          0.000270    0.7650    0.347  122.624
# 41       0.0351        0.0218          0.000204    0.0923    0.793  108.498
# 42       0.0271        0.0155          0.005730    0.0917    0.807  124.644
# 43       0.0341        0.1540          0.000000    0.1230    0.494  117.913
# 44       0.0305        0.0193          0.006840    0.0987    0.867  104.970
#
#     time_signature  cluster_number  km_nn9_nc3
# 40               4             1.0         0.0
# 41               4             1.0         0.0
# 42               4             1.0         0.0
# 43               4             1.0         0.0
# 44               4             1.0         0.0
#
# [5 rows x 24 columns]
# ['artist_uri', 'artist_name', 'albumn_name', 'albumn_release_date', 'albumn_total_tracks', 'duration_ms', 'explicit', 'track_name', 'track_popularity', 'track_uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'cluster_number', 'km_nn9_nc3']

# %%
artists_cluster = pd.read_csv('{}/clusters/uri_map_1st_cluster.csv'.format(DATA_PATH))
print("{} x {} table of data:".format(artists_cluster.shape[0], artists_cluster.shape[1]))
display(artists_cluster.head ())
print("Remove any N/As...\n\n")
artists_cluster = artists_cluster.dropna()
print("{} x {} table of data:".format(artists_cluster.shape[0], artists_cluster.shape[1]))
display(artists_cluster.head ())
print(artists_cluster.columns)
# Out:
# 764 x 14 table of data:
#                                      uri                           name  \
# 0  spotify:artist:001aJOc7CSQVo3XzoLG4DK                        One Way
# 1  spotify:artist:00tVTdpEhQQw1bqdu8RCx2               Blue Öyster Cult
# 2  spotify:artist:01Ppu7N8uYJI8SAONo2YZA              Melissa Etheridge
# 3  spotify:artist:01W8kYNqFHyKicPfR0pLwO  England Dan & John Ford Coley
# 4  spotify:artist:01Wck2m10xhdxUrLaMq60y                  Rene & Angela
#
#    iso_nn6_nc2_1  iso_nn6_nc2_2  se_nn6_nc2_1  se_nn6_nc2_2  km_nn6_nc2  \
# 0       1.947724       0.381297      0.011542     -0.005389           5
# 1      -0.371263      -0.298362     -0.011971      0.000754           0
# 2      -1.574281      -1.279214     -0.013082      0.001587           0
# 3      -1.479115      -2.381933     -0.011531      0.000668           4
# 4       1.986850       0.062321      0.012193     -0.005265           5
#
#    iso_nn9_nc3_1  iso_nn9_nc3_2  iso_nn9_nc3_3  se_nn9_nc3_1  se_nn9_nc3_2  \
# 0      -1.013131      -0.521066       0.532044      0.011542     -0.005389
# 1      -0.941251      -0.053596       0.484134     -0.011971      0.000754
# 2      -0.749857      -0.253648      -1.141207     -0.013082      0.001587
# 3      -1.899376      -2.130514      -1.088571     -0.011531      0.000668
# 4      -0.556372      -0.860712       0.506586      0.012193     -0.005265
#
#    se_nn9_nc3_3  km_nn9_nc3
# 0     -0.014752           5
# 1     -0.004029           0
# 2      0.053016           0
# 3     -0.002429           4
# 4     -0.013879           5
# Remove any N/As...
#
#
# 764 x 14 table of data:
#                                      uri                           name  \
# 0  spotify:artist:001aJOc7CSQVo3XzoLG4DK                        One Way
# 1  spotify:artist:00tVTdpEhQQw1bqdu8RCx2               Blue Öyster Cult
# 2  spotify:artist:01Ppu7N8uYJI8SAONo2YZA              Melissa Etheridge
# 3  spotify:artist:01W8kYNqFHyKicPfR0pLwO  England Dan & John Ford Coley
# 4  spotify:artist:01Wck2m10xhdxUrLaMq60y                  Rene & Angela
#
#    iso_nn6_nc2_1  iso_nn6_nc2_2  se_nn6_nc2_1  se_nn6_nc2_2  km_nn6_nc2  \
# 0       1.947724       0.381297      0.011542     -0.005389           5
# 1      -0.371263      -0.298362     -0.011971      0.000754           0
# 2      -1.574281      -1.279214     -0.013082      0.001587           0
# 3      -1.479115      -2.381933     -0.011531      0.000668           4
# 4       1.986850       0.062321      0.012193     -0.005265           5
#
#    iso_nn9_nc3_1  iso_nn9_nc3_2  iso_nn9_nc3_3  se_nn9_nc3_1  se_nn9_nc3_2  \
# 0      -1.013131      -0.521066       0.532044      0.011542     -0.005389
# 1      -0.941251      -0.053596       0.484134     -0.011971      0.000754
# 2      -0.749857      -0.253648      -1.141207     -0.013082      0.001587
# 3      -1.899376      -2.130514      -1.088571     -0.011531      0.000668
# 4      -0.556372      -0.860712       0.506586      0.012193     -0.005265
#
#    se_nn9_nc3_3  km_nn9_nc3
# 0     -0.014752           5
# 1     -0.004029           0
# 2      0.053016           0
# 3     -0.002429           4
# 4     -0.013879           5
# Index(['uri', 'name', 'iso_nn6_nc2_1', 'iso_nn6_nc2_2', 'se_nn6_nc2_1',
#        'se_nn6_nc2_2', 'km_nn6_nc2', 'iso_nn9_nc3_1', 'iso_nn9_nc3_2',
#        'iso_nn9_nc3_3', 'se_nn9_nc3_1', 'se_nn9_nc3_2', 'se_nn9_nc3_3',
#        'km_nn9_nc3'],
#       dtype='object')

# %%
joined_df = pd.merge(spotify_artists_top_tracks_df, artists_cluster, left_on="artist_uri", right_on="uri", how="inner")
joined_df = joined_df[['artist_uri', 'albumn_name', 'albumn_release_date',
       'albumn_total_tracks', 'duration_ms', 'explicit', 'track_name',
       'track_popularity', 'track_uri', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature']]
print("{} x {} table of data:".format(joined_df.shape[0], joined_df.shape[1]))
display(joined_df.head (10))

spotify_artists_top_tracks_df = joined_df
print(joined_df.columns)
# Out:
# 3872 x 21 table of data:
#                               artist_uri  \
# 0  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 1  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 2  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 3  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 4  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 5  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 6  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 7  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 8  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
# 9  spotify:artist:0MBIKH9DjtBkv8O3nS6szj
#
#                                          albumn_name albumn_release_date  \
# 0                                      MTV Unplugged          10/26/1993
# 1                                   Our Time in Eden                1992
# 2                               Love Among The Ruins            1/1/1997
# 3                                    Blind Man's Zoo            5/2/1989
# 4                                   Our Time in Eden                1992
# 5                                        In My Tribe           7/27/1987
# 6                                        In My Tribe           7/27/1987
# 7  Campfire Songs: The Popular, Obscure and Unkno...           2/17/2004
# 8  Campfire Songs: The Popular, Obscure and Unkno...           2/17/2004
# 9                                        In My Tribe           7/27/1987
#
#    albumn_total_tracks  duration_ms  explicit  \
# 0                   14       223373     False
# 1                   13       219893     False
# 2                   12       245573     False
# 3                   11       193560     False
# 4                   13       185960     False
# 5                   11       236653     False
# 6                   11       206413     False
# 7                   31       208200     False
# 8                   31       255666     False
# 9                   11       289026     False
#
#                            track_name  track_popularity  \
# 0  Because the Night - Live Unplugged                61
# 1                      These Are Days                56
# 2                      More Than This                53
# 3                          Trouble Me                50
# 4               Candy Everybody Wants                47
# 5                    Like the Weather                45
# 6                    Hey Jack Kerouac                43
# 7                         Peace Train                43
# 8                    To Sir with Love                42
# 9             What's the Matter Here?                40
#
#                               track_uri  danceability  ...  key  loudness  \
# 0  spotify:track:5VzvK7YiwWbRePA2JOzhYq         0.408  ...   11    -8.138
# 1  spotify:track:786h4kDeZiX5nYvOwA3wtE         0.611  ...    3    -7.554
# 2  spotify:track:5v6b9RUk83Z33shcsqt1m3         0.623  ...    6    -8.800
# 3  spotify:track:5nLhswlXx18vI65KkKKFgx         0.861  ...    2   -10.057
# 4  spotify:track:32xXojNvbRTQ9qfb3mWR69         0.622  ...   10    -6.310
# 5  spotify:track:19X5dUlxVWC5jDg3eOysMz         0.770  ...    1   -17.453
# 6  spotify:track:3jJDFiNmHsU18FxvklXwIK         0.616  ...    6   -15.894
# 7  spotify:track:1w55KYUy9raksnb56nvScq         0.666  ...    9    -8.469
# 8  spotify:track:5e4AzYhsqefoINOnqChSK1         0.424  ...    0    -5.920
# 9  spotify:track:0oyj088gTacb4sWeMBBpfb         0.586  ...    9   -16.305
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.1030        0.2600          0.000270    0.7650    0.347
# 1     1       0.0351        0.0218          0.000204    0.0923    0.793
# 2     1       0.0271        0.0155          0.005730    0.0917    0.807
# 3     1       0.0341        0.1540          0.000000    0.1230    0.494
# 4     1       0.0305        0.0193          0.006840    0.0987    0.867
# 5     1       0.0416        0.1120          0.003430    0.1450    0.963
# 6     1       0.0279        0.0384          0.000000    0.1500    0.604
# 7     1       0.0297        0.0652          0.000000    0.0870    0.826
# 8     1       0.0329        0.1110          0.000005    0.9710    0.342
# 9     1       0.0398        0.0110          0.000124    0.0741    0.585
#
#      tempo  time_signature
# 0  122.624               4
# 1  108.498               4
# 2  124.644               4
# 3  117.913               4
# 4  104.970               4
# 5  133.351               4
# 6  132.015               4
# 7  155.371               4
# 8  100.614               4
# 9   99.980               4
#
# [10 rows x 21 columns]
# Index(['artist_uri', 'albumn_name', 'albumn_release_date',
#        'albumn_total_tracks', 'duration_ms', 'explicit', 'track_name',
#        'track_popularity', 'track_uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
def make_normalized_df(df, col_sep):
    non_features = df[df.columns[:col_sep]]
    features = df[df.columns[col_sep:]]
    norm = MinMaxScaler().fit_transform(features)
    scaled = pd.DataFrame(norm, index=df.index, columns = df.columns[col_sep:])
    return pd.concat([non_features, scaled], axis=1)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]
df1 = make_normalized_df(spotify_artists_top_tracks_df[columns], 0)
data = df1.values.tolist()

# temp = data[:1000]
# temp = [data[i] for i in randi]
print(data[0])
data1 = [i.append(i[0]) or i for i in data]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# [0.35472857630590643, 0.791112021298382, 1.0, 0.770213486953575, 0.0, 0.09111361079865017, 0.26130299137212953, 0.00028421052631578947, 0.773952716715056, 0.3299023211847495, 0.4023737901348]

# %% [markdown]
# ## Principal Components Analysis on the Track Characteristics

# %% [markdown]
# ### PCA on tracks to see if there are any clusters in 2 dimensions

# %%
# Build the data matrix and condition it

columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]
df1 = spotify_artists_top_tracks_df[columns]
scaler = StandardScaler()
df1 = scaler.fit_transform(df1)

D_raw = df1
D_raw = D_raw.T

m, d = D_raw.shape
print("D_raw:", D_raw.shape)
# Out:
# D_raw: (11, 3872)

# %%
pca = PCA(n_components = 2)
prin_comps = pca.fit(D_raw);

print(len(prin_comps.components_[0]))
# prin_comp_1 = prin_comps[:, 0]
# prin_comp_2  = prin_comps[:, 1]

figure, axes = plt.subplots(figsize = (8,8))
axes.scatter(prin_comps.components_[0], prin_comps.components_[1])
# Out:
# 3872

# %% [markdown]
# ### PCA on track features to see if there are any clusters in 2 dimensions

# %%
# Build the data matrix and condition it

columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]
df1 = spotify_artists_top_tracks_df[columns]
scaler = StandardScaler()
df1 = scaler.fit_transform(df1)
D_raw = df1

m, d = D_raw.shape
print("D_raw:", D_raw.shape)
# Out:
# D_raw: (3872, 11)

# %%
pca = PCA(n_components = 2)
prin_comps = pca.fit(D_raw);

print(len(prin_comps.components_[0]))
figure, axes = plt.subplots(figsize = (8,8))
axes.scatter(prin_comps.components_[0], prin_comps.components_[1])

for i in range(0, len(columns)):

    plt.annotate(columns[i], # this is the text
                 (prin_comps.components_[0][i], prin_comps.components_[1][i]), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(5,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
# Out:
# 11

# %% [markdown]
# ### PCA on track features to reduce dimensionality

# %%
pca = PCA()
pca.fit(D_raw);

evr = pca.explained_variance_ratio_
print(evr.shape)
fig = plt.figure(figsize=(10,8))
plt.plot(range(1, D_raw.shape[1]+1), evr.cumsum(), marker='o', linestyle='--')
plt.xlabel('Number of Components', fontsize=18)
plt.ylabel('Cumulative Explained Variance',fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# fig = plt.savefig("./visualizations/cumulative_variance_plot.png")
plt.show()
# Out:
# (11,)

# %%
n_comps = 7
pca = PCA(n_components = n_comps)
prin_comps = pca.fit(D_raw);
D_pca = pca.transform(D_raw)

print("D_pca: ", D_pca.shape)
# Out:
# D_pca:  (3872, 7)

# %% [markdown]
# ### K Means on reduced dimension dataset

# %%
Sum_of_squared_distances = []
K = range(1,20)
for num_clusters in K :
 kmeans = KMeans(n_clusters=num_clusters, init='k-means++', random_state=10)
 kmeans.fit(D_pca)
 Sum_of_squared_distances.append(kmeans.inertia_)
plt.plot(K,Sum_of_squared_distances,"bx-")
plt.xlabel("Values of K") 
plt.ylabel("Sum of squared distances/Inertia") 
plt.title("Elbow Method For Optimal k")
plt.show()

# %%
n_clusters = 7
kmeans_pca = KMeans(n_clusters=n_clusters, init='k-means++', random_state=10)
kmeans_pca.fit(D_pca);

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]
df1 = spotify_artists_top_tracks_df[columns]
df_seg_pca_kmeans = pd.concat([df1.reset_index(drop=True), pd.DataFrame(D_pca)], axis=1)
df_seg_pca_kmeans.columns.values[(-1*n_comps):] = ["Component " + str(i+1) for i in range(n_comps)]
df_seg_pca_kmeans['Cluster'] = kmeans_pca.labels_
df_seg_pca_kmeans.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.408   0.790   11    -8.138     0       0.1030        0.2600
# 1         0.611   0.833    3    -7.554     1       0.0351        0.0218
# 2         0.623   0.773    6    -8.800     1       0.0271        0.0155
# 3         0.861   0.385    2   -10.057     1       0.0341        0.1540
# 4         0.622   0.876   10    -6.310     1       0.0305        0.0193
#
#    instrumentalness  liveness  valence    tempo  Component 1  Component 2  \
# 0          0.000270    0.7650    0.347  122.624    -0.455207     1.782148
# 1          0.000204    0.0923    0.793  108.498    -1.261138     0.308573
# 2          0.005730    0.0917    0.807  124.644    -1.040315     0.152160
# 3          0.000000    0.1230    0.494  117.913     0.462662    -0.889432
# 4          0.006840    0.0987    0.867  104.970    -1.690743    -0.070306
#
#    Component 3  Component 4  Component 5  Component 6  Component 7  Cluster
# 0    -3.369668    -0.669145     0.096447     2.005528    -0.937012        1
# 1     1.352183     0.027480    -0.730610    -0.345444    -0.116979        2
# 2     0.923172     0.472627    -0.273654    -0.626544    -0.773189        2
# 3     1.254353    -0.632472    -0.175065    -0.391319     0.362869        2
# 4     0.326507     0.887853    -1.021734    -0.258590    -1.321548        2

# %%
x = df_seg_pca_kmeans['Component 2']
y = df_seg_pca_kmeans['Component 1']
fig = plt.figure(figsize=(10, 8))
sns.scatterplot(x, y, hue=df_seg_pca_kmeans['Cluster'], palette = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'goldenrod', 'tab:cyan'])
plt.title('Clusters by PCA Components', fontsize=20)
plt.xlabel("Component 2", fontsize=18)
plt.ylabel("Component 1", fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()
# Out:
# C:\Users\19197\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
spotify_artists_top_tracks_df['Cluster'] = df_seg_pca_kmeans['Cluster']
display(spotify_artists_top_tracks_df.head())
# Out:
#                               artist_uri           albumn_name  \
# 0  spotify:artist:0MBIKH9DjtBkv8O3nS6szj         MTV Unplugged
# 1  spotify:artist:0MBIKH9DjtBkv8O3nS6szj      Our Time in Eden
# 2  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  Love Among The Ruins
# 3  spotify:artist:0MBIKH9DjtBkv8O3nS6szj       Blind Man's Zoo
# 4  spotify:artist:0MBIKH9DjtBkv8O3nS6szj      Our Time in Eden
#
#   albumn_release_date  albumn_total_tracks  duration_ms  explicit  \
# 0          10/26/1993                   14       223373     False
# 1                1992                   13       219893     False
# 2            1/1/1997                   12       245573     False
# 3            5/2/1989                   11       193560     False
# 4                1992                   13       185960     False
#
#                            track_name  track_popularity  \
# 0  Because the Night - Live Unplugged                61
# 1                      These Are Days                56
# 2                      More Than This                53
# 3                          Trouble Me                50
# 4               Candy Everybody Wants                47
#
#                               track_uri  danceability  ...  loudness  mode  \
# 0  spotify:track:5VzvK7YiwWbRePA2JOzhYq         0.408  ...    -8.138     0
# 1  spotify:track:786h4kDeZiX5nYvOwA3wtE         0.611  ...    -7.554     1
# 2  spotify:track:5v6b9RUk83Z33shcsqt1m3         0.623  ...    -8.800     1
# 3  spotify:track:5nLhswlXx18vI65KkKKFgx         0.861  ...   -10.057     1
# 4  spotify:track:32xXojNvbRTQ9qfb3mWR69         0.622  ...    -6.310     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1030        0.2600          0.000270    0.7650    0.347  122.624
# 1       0.0351        0.0218          0.000204    0.0923    0.793  108.498
# 2       0.0271        0.0155          0.005730    0.0917    0.807  124.644
# 3       0.0341        0.1540          0.000000    0.1230    0.494  117.913
# 4       0.0305        0.0193          0.006840    0.0987    0.867  104.970
#
#    time_signature  Cluster
# 0               4        1
# 1               4        2
# 2               4        2
# 3               4        2
# 4               4        2
#
# [5 rows x 22 columns]

# %%
def make_normalized_df(df, col_sep):
    non_features = df[df.columns[:col_sep]]
    features = df[df.columns[col_sep:]]
    norm = MinMaxScaler().fit_transform(features)
    scaled = pd.DataFrame(norm, index=df.index, columns = df.columns[col_sep:])
    return pd.concat([non_features, scaled], axis=1)

cluster_labels = spotify_artists_top_tracks_df['Cluster']
orig = spotify_artists_top_tracks_df.drop(columns=['Cluster'])
values_df = make_normalized_df(orig, 9)
values_df.insert(3, 'cluster', cluster_labels)
values_df.head()
# Out:
#                               artist_uri           albumn_name  \
# 0  spotify:artist:0MBIKH9DjtBkv8O3nS6szj         MTV Unplugged
# 1  spotify:artist:0MBIKH9DjtBkv8O3nS6szj      Our Time in Eden
# 2  spotify:artist:0MBIKH9DjtBkv8O3nS6szj  Love Among The Ruins
# 3  spotify:artist:0MBIKH9DjtBkv8O3nS6szj       Blind Man's Zoo
# 4  spotify:artist:0MBIKH9DjtBkv8O3nS6szj      Our Time in Eden
#
#   albumn_release_date  cluster  albumn_total_tracks  duration_ms  explicit  \
# 0          10/26/1993        1                   14       223373     False
# 1                1992        2                   13       219893     False
# 2            1/1/1997        2                   12       245573     False
# 3            5/2/1989        2                   11       193560     False
# 4                1992        2                   13       185960     False
#
#                            track_name  track_popularity  \
# 0  Because the Night - Live Unplugged                61
# 1                      These Are Days                56
# 2                      More Than This                53
# 3                          Trouble Me                50
# 4               Candy Everybody Wants                47
#
#                               track_uri  ...       key  loudness  mode  \
# 0  spotify:track:5VzvK7YiwWbRePA2JOzhYq  ...  1.000000  0.770213   0.0
# 1  spotify:track:786h4kDeZiX5nYvOwA3wtE  ...  0.272727  0.790003   1.0
# 2  spotify:track:5v6b9RUk83Z33shcsqt1m3  ...  0.545455  0.747780   1.0
# 3  spotify:track:5nLhswlXx18vI65KkKKFgx  ...  0.181818  0.705185   1.0
# 4  spotify:track:32xXojNvbRTQ9qfb3mWR69  ...  0.909091  0.832159   1.0
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     0.091114      0.261303          0.000284  0.773953  0.329902  0.402374
# 1     0.014736      0.021905          0.000215  0.076421  0.798341  0.313476
# 2     0.005737      0.015573          0.006032  0.075798  0.813045  0.415086
# 3     0.013611      0.154770          0.000000  0.108254  0.484298  0.372727
# 4     0.009561      0.019392          0.007200  0.083057  0.876063  0.291274
#
#    time_signature
# 0            0.75
# 1            0.75
# 2            0.75
# 3            0.75
# 4            0.75
#
# [5 rows x 22 columns]

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 0]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 759

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 1]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 273

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 2]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 1020

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 3]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 752

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 4]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 106

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 5]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 229

# %%
columns = ["danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"]

temp = values_df[values_df["cluster"] == 6]
temp = temp[columns]
temp = temp.values.tolist()

# temp = [data[i] for i in randi]
print(len(temp))
data1 = [i.append(i[0]) or i for i in temp]
# print(data1[0])


# Initialise the spider plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
# print(columns)
angles = [n / float(len(columns)) * 2 * pi for n in range(len(columns))]
angles += angles[:1]

# print(angles)

# Draw one axe per variable + add labels
plt.xticks(angles[:-1], columns, color='white', size=8)



# Plot data
for i in data1:
    ax.plot(angles, i, linewidth=1, linestyle='solid')

    
# Show the graph
plt.show()
# Out:
# 733
